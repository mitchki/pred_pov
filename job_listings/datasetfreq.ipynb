# %%
import pandas as pd
import nltk
total_df = pd.read_pickle('total_df.pkl')

# %%
keys = total_df.groupby('keyword').count()
keys
# Out:
#                 city  company  title  summary
# keyword
# data+analyst    6960     6960   6960     6960
# data+architect  5603     5603   5603     5603
# data+engineer   7000     7000   7000     7000
# data+scientist  4180     4180   4180     4180
# statistician    2973     2973   2973     2973

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sb

# %%
x = total_df.keyword.value_counts().plot(kind='bar');
plt.title('Frequencies of keywords in dataset')
# Out:
# Axes(0.125,0.125;0.775x0.775)

# %%
x = total_df.city.value_counts().plot(kind='bar');
plt.title('Frequencies of cities in dataset')

# %%
#table = pivot_table(df, values='D', index=['A', 'B'],
#...                     columns=['C'], aggfunc=np.sum)

ct = pd.crosstab(total_df.city,total_df.keyword)

# %%
import seaborn as sb
fig, ax = plt.subplots(figsize=(10, 8))
sb.heatmap(ct, annot=True);

# %%
tfd = nltk.FreqDist(text1)

# %%
fd.plot(50,cumulative=False)

# %%
fd.tabulate()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-f0f79c0d0860> in <module>()
# ----> 1 fd.tabulate()
#
# NameError: name 'fd' is not defined
