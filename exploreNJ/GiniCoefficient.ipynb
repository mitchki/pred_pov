# %% [markdown]
# ## Calculate estimate of gini coefficient for each municipality

# %%
import pandas as pd

df = pd.read_pickle('d2.pkl')

# %%
df.columns[39:51]
# Out:
# Index(['p_less10', 'p_10to15', 'p_15to25', 'p_25to35', 'p_35to50', 'p_50to75',
#        'p_75to100', 'p_100to150', 'p_150to200', 'p_over200', 'hh_inc_med',
#        'hh_inc_mean'],
#       dtype='object')

# %%
df_gini = pd.concat([df.iloc[:,:5], df.iloc[:,39:50]],axis=1)
#result = pd.concat([df1, df4], axis=1, join='inner')

# %%
df_gini.describe()
# Out:
#          p_less10    p_10to15    p_15to25    p_25to35    p_35to50    p_50to75  \
# count  565.000000  565.000000  565.000000  565.000000  565.000000  565.000000
# mean     4.037876    3.124071    7.338938    7.146549   10.048496   16.099469
# std      3.233197    2.318677    4.547789    3.448837    3.928034    4.613615
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      2.000000    1.600000    4.600000    4.600000    7.200000   13.200000
# 50%      3.200000    2.600000    6.600000    6.800000    9.900000   16.200000
# 75%      5.300000    4.000000    9.400000    9.200000   12.700000   19.300000
# max     24.100000   15.200000   71.400000   28.600000   25.700000   32.200000
#
#         p_75to100  p_100to150  p_150to200   p_over200     hh_inc_med
# count  565.000000  565.000000  565.000000  565.000000     565.000000
# mean    13.256991   18.070088    9.293982   11.585487   83768.166372
# std      3.771389    5.449296    4.581809   11.526807   30141.993205
# min      0.000000    0.000000    0.000000    0.000000       0.000000
# 25%     10.700000   14.900000    5.700000    3.800000   63017.000000
# 50%     13.200000   18.500000    9.200000    8.000000   78132.000000
# 75%     15.700000   21.500000   12.400000   16.500000  102168.000000
# max     27.600000   45.700000   23.600000  100.000000  194536.000000

# %% [markdown]
# ### Share of income per bin
#
# With binned data, estimate income at center of bin
# Except top bin of Over 200K estimate at 1.5*200K = 300K
#
# income_share = bin_midpoint * %_share_of_households

# %%
df_gini['incshare_less10'] = df_gini['p_less10'] * 5000 * 0.01
df_gini['incshare_10to15'] = df_gini['p_10to15'] * 12500 * 0.01
df_gini['incshare_15to25'] = df_gini['p_15to25'] * 20000 * 0.01
df_gini['incshare_25to35'] = df_gini['p_25to35'] * 30000 * 0.01
df_gini['incshare_35to50'] = df_gini['p_35to50'] * 42500 * 0.01
df_gini['incshare_50to75'] = df_gini['p_50to75'] * 62500 * 0.01
df_gini['incshare_75to100'] = df_gini['p_75to100'] * 87500 * 0.01
df_gini['incshare_100to150'] = df_gini['p_100to150'] * 125000 * 0.01
df_gini['incshare_150to200'] = df_gini['p_150to200'] * 175000 * 0.01
df_gini['incshare_over200'] = df_gini['p_over200'] * 300000 * 0.01

# %%
## Cumulative share of population
df_gini['cumpop_less10'] = df_gini['p_less10'] 
df_gini['cumpop_10to15'] = df_gini['p_10to15'] + df_gini['cumpop_less10']
df_gini['cumpop_15to25'] = df_gini['p_15to25'] + df_gini['cumpop_10to15']
df_gini['cumpop_25to35'] = df_gini['p_25to35'] + df_gini['cumpop_15to25'] 
df_gini['cumpop_35to50'] = df_gini['p_35to50'] + df_gini['cumpop_25to35'] 
df_gini['cumpop_50to75'] = df_gini['p_50to75'] + df_gini['cumpop_35to50']
df_gini['cumpop_75to100'] = df_gini['p_75to100'] + df_gini['cumpop_50to75']
df_gini['cumpop_100to150'] = df_gini['p_100to150'] + df_gini['cumpop_75to100']
df_gini['cumpop_150to200'] = df_gini['p_150to200'] + df_gini['cumpop_100to150'] 
df_gini['cumpop_over200'] = df_gini['p_over200'] + df_gini['cumpop_150to200']

# %%
df_gini['cuminc_less10'] = df_gini['incshare_less10'] 
df_gini['cuminc_10to15'] = df_gini['incshare_10to15'] + df_gini['cuminc_less10']
df_gini['cuminc_15to25'] = df_gini['incshare_15to25'] + df_gini['cuminc_10to15']
df_gini['cuminc_25to35'] = df_gini['incshare_25to35'] + df_gini['cuminc_15to25'] 
df_gini['cuminc_35to50'] = df_gini['incshare_35to50'] + df_gini['cuminc_25to35'] 
df_gini['cuminc_50to75'] = df_gini['incshare_50to75'] + df_gini['cuminc_35to50']
df_gini['cuminc_75to100'] = df_gini['incshare_75to100'] + df_gini['cuminc_50to75']
df_gini['cuminc_100to150'] = df_gini['incshare_100to150'] + df_gini['cuminc_75to100']
df_gini['cuminc_150to200'] = df_gini['incshare_150to200'] + df_gini['cuminc_100to150'] 
df_gini['cuminc_over200'] = df_gini['incshare_over200'] + df_gini['cuminc_150to200']

# %%
df_gini['tot_inc'] = df_gini['cuminc_over200']

# %%
df_gini['p_cuminc_less10'] = df_gini['cuminc_less10'] / df_gini['tot_inc']
df_gini['p_cuminc_10to15'] = df_gini['cuminc_10to15']  / df_gini['tot_inc']
df_gini['p_cuminc_15to25'] = df_gini['cuminc_15to25']  / df_gini['tot_inc']
df_gini['p_cuminc_25to35'] = df_gini['cuminc_25to35']   / df_gini['tot_inc']
df_gini['p_cuminc_35to50'] = df_gini['cuminc_35to50']   / df_gini['tot_inc']
df_gini['p_cuminc_50to75'] = df_gini['cuminc_50to75']  / df_gini['tot_inc']
df_gini['p_cuminc_75to100'] = df_gini['cuminc_75to100']  / df_gini['tot_inc']
df_gini['p_cuminc_100to150'] = df_gini['cuminc_100to150']  / df_gini['tot_inc']
df_gini['p_cuminc_150to200'] = df_gini['cuminc_150to200']   / df_gini['tot_inc']
df_gini['p_cuminc_over200'] = df_gini['cuminc_over200']   / df_gini['tot_inc']

# %%
df_gini.head()
# Out:
#                    town            county        state        FIPS  \
# 0          Absecon city   Atlantic County   New Jersey  3400100100
# 1    Atlantic City city   Atlantic County   New Jersey  3400102080
# 2       Brigantine city   Atlantic County   New Jersey  3400107810
# 3         Buena borough   Atlantic County   New Jersey  3400108680
# 4  Buena Vista township   Atlantic County   New Jersey  3400108710
#
#                                            city_town  p_less10  p_10to15  \
# 0          Absecon city, Atlantic County, New Jersey       2.0       0.9
# 1    Atlantic City city, Atlantic County, New Jersey      18.5      10.8
# 2       Brigantine city, Atlantic County, New Jersey       4.7       3.9
# 3         Buena borough, Atlantic County, New Jersey       6.6       7.5
# 4  Buena Vista township, Atlantic County, New Jersey       4.9       8.2
#
#    p_15to25  p_25to35  p_35to50        ...         p_cuminc_less10  \
# 0       7.4      14.0      15.5        ...                0.001226
# 1      18.1      12.7      14.0        ...                0.022146
# 2      13.5      11.0      13.3        ...                0.003004
# 3      12.2      13.0      14.6        ...                0.005038
# 4       7.5       9.5      15.8        ...                0.003535
#
#    p_cuminc_10to15  p_cuminc_15to25  p_cuminc_25to35  p_cuminc_35to50  \
# 0         0.002605         0.020747         0.072230         0.152979
# 1         0.054468         0.141138         0.232358         0.374813
# 2         0.009235         0.043745         0.085924         0.158172
# 3         0.019351         0.056603         0.116145         0.210878
# 4         0.018327         0.039973         0.081100         0.178001
#
#    p_cuminc_50to75  p_cuminc_75to100  p_cuminc_100to150  p_cuminc_150to200  \
# 0         0.323057          0.475362           0.656166           0.797745
# 1         0.555875          0.677381           0.821033           0.892261
# 2         0.280396          0.407893           0.631571           0.808276
# 3         0.320611          0.534351           0.767176           0.858015
# 4         0.388145          0.572495           0.720408           0.813846
#
#    p_cuminc_over200
# 0               1.0
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0
#
# [5 rows x 57 columns]

# %%
B_less10 = df_gini['p_less10'] * 0.01 * df_gini['p_cuminc_less10'] * 0.5
B_10to15 = ((df_gini['p_less10']*0.01*df_gini['p_cuminc_less10']) + (df_gini['p_10to15']*0.01*df_gini['p_cuminc_10to15'])) / 2
B_15to25 = ((df_gini['p_10to15']*0.01*df_gini['p_cuminc_10to15']) + (df_gini['p_15to25']*0.01*df_gini['p_cuminc_15to25'])) / 2
B_25to35 = ((df_gini['p_15to25']*0.01*df_gini['p_cuminc_15to25']) + (df_gini['p_25to35']*0.01*df_gini['p_cuminc_25to35'])) / 2
B_35to50 = ((df_gini['p_25to35']*0.01*df_gini['p_cuminc_25to35']) + (df_gini['p_35to50']*0.01*df_gini['p_cuminc_35to50'])) / 2
B_50to75 = ((df_gini['p_35to50']*0.01*df_gini['p_cuminc_35to50']) + (df_gini['p_50to75']*0.01*df_gini['p_cuminc_50to75'])) / 2
B_75to100 = ((df_gini['p_50to75']*0.01*df_gini['p_cuminc_50to75']) + (df_gini['p_75to100']*0.01*df_gini['p_cuminc_75to100'])) / 2
B_100to150 = ((df_gini['p_75to100']*0.01*df_gini['p_cuminc_75to100']) + (df_gini['p_100to150']*0.01*df_gini['p_cuminc_100to150'])) / 2
B_150to200 = ((df_gini['p_100to150']*0.01*df_gini['p_cuminc_100to150']) + (df_gini['p_150to200']*0.01*df_gini['p_cuminc_150to200'])) / 2
B_over200 = ((df_gini['p_150to200']*0.01*df_gini['p_cuminc_150to200']) + (df_gini['p_over200']*0.01*df_gini['p_cuminc_over200'])) / 2

# %%
B = B_less10 + B_10to15 + B_15to25 + B_25to35 + B_35to50 + B_50to75 + B_75to100 + B_100to150 + B_150to200 + B_over200

# %%
df_gini['gini'] = 1 - (2*B)

# %%
df_gini['gini'].describe()
# Out:
# count    565.000000
# mean       0.346654
# std        0.081611
# min       -0.464031
# 25%        0.298138
# 50%        0.346907
# 75%        0.405243
# max        0.506263
# Name: gini, dtype: float64

# %%
df_gini.sort_values('gini')
# Out:
#                               town              county        state  \
# 213  3401347500       Montclair township, Essex County, New Jersey       5.1
# 331  3402516660          Deal borough, Monmouth County, New Jersey       3.3
# 256  3401777930      Weehawken township, Hudson County, New Jersey       6.2
# 322  3402500730    Allenhurst borough, Monmouth County, New Jersey       3.3
# 429  3402941250      Long Beach township, Ocean County, New Jersey       7.3
# 80   3400365400    Saddle River borough, Bergen County, New Jersey       2.3
# 421  3402930390    Harvey Cedars borough, Ocean County, New Jersey       3.2
# 324  3402501960      Asbury Park city, Monmouth County, New Jersey      14.5
# 355  3402547130  Monmouth Beach borough, Monmouth County, New J...       4.4
# 170  3400902320        Avalon borough, Cape May County, New Jersey       4.8
# 179  3400971010  Stone Harbor borough, Cape May County, New Jersey       6.6
#
#      p_10to15  p_15to25  p_25to35  p_35to50    ...     p_cuminc_10to15  \
# 520       0.0      71.4      28.6       0.0    ...            0.000000
# 161       0.0       0.0       0.0       0.0    ...            0.000000
# 165       0.0       0.0       0.0       0.0    ...            0.000000
# 273       0.8       3.9       4.2       7.8    ...            0.000851
# 475       0.7       3.7       4.8       9.0    ...            0.000919
# 196       0.0       1.4      11.5       9.7    ...            0.004860
# 8         1.4       6.4       6.9       4.4    ...            0.002451
# 462       3.1       3.5       6.7      12.8    ...            0.007177
# 128       0.0       3.2       8.8      14.4    ...            0.000607
# 464       2.2       8.6      10.4       9.6    ...            0.006481
# 301       0.0       6.6       5.8      14.0    ...            0.000947
# 188       2.2       5.9       5.3       9.2    ...            0.004430
# 466       3.8      10.7       3.1      10.1    ...            0.006041
# 172       0.9      13.0       7.0      19.1    ...            0.002308
# 173       3.7       6.9       8.8      13.8    ...            0.008030
# 370       3.8       4.4       6.0      10.7    ...            0.006232
# 511       6.9       7.1       6.2      17.4    ...            0.014094
# 425       3.1       6.7      17.4      10.5    ...            0.006997
# 559       2.4      11.7       6.3       5.9    ...            0.005552
# 139       2.1       7.7      10.9      13.1    ...            0.008929
# 556       3.3       4.6       5.2      10.8    ...            0.008065
# 151       0.9      10.1      12.5      22.3    ...            0.008466
# 197       0.5       7.5       9.8      10.5    ...            0.003964
# 134       4.0      14.4      15.2      20.8    ...            0.013698
# 167       2.2       5.9       5.0      12.2    ...            0.004826
# 500       2.5      12.5       9.7       9.7    ...            0.007481
# 138       6.9      12.2       6.7       6.3    ...            0.013098
# 7         3.1       9.2      13.8      23.7    ...            0.011820
# 233       3.3      12.6       4.6      12.1    ...            0.006826
# 473       3.7      13.0       7.5      12.1    ...            0.008809
# ..        ...       ...       ...       ...    ...                 ...
# 211       1.0       7.3       4.1       6.0    ...            0.001835
# 24        2.5       8.9       1.2       5.2    ...            0.002559
# 251       5.9      10.6       8.1      10.8    ...            0.013697
# 291       2.7       7.6       4.4       5.0    ...            0.003247
# 51        4.0       4.9       9.3      10.1    ...            0.007059
# 37        5.0       6.3       5.9      11.6    ...            0.009051
# 248       4.6      16.5       7.7       9.1    ...            0.012035
# 474      11.9      16.4      12.2      11.2    ...            0.049749
# 307       3.3       8.5       9.1      11.8    ...            0.005733
# 539       1.2       5.2       3.6       8.1    ...            0.002264
# 497       2.1       6.8       7.5       8.9    ...            0.002339
# 14        1.2      11.1       8.5      11.5    ...            0.002529
# 65        1.9       3.5       4.0      12.2    ...            0.002375
# 375       4.2       5.3       5.1       5.1    ...            0.005277
# 292       1.6       3.9       7.0       6.2    ...            0.002600
# 384       6.0       5.8       5.1       5.8    ...            0.005217
# 379       4.2       8.1       3.7       8.8    ...            0.006640
# 363       5.8      12.1       7.3       9.1    ...            0.007025
# 339       2.6      14.5       3.2       8.0    ...            0.006514
# 213       2.5       5.6       5.5       7.6    ...            0.004322
# 331       6.4      11.5      10.3       5.5    ...            0.009067
# 256       2.4      10.3       5.9      10.3    ...            0.005709
# 322       6.1       1.9       6.6      12.2    ...            0.007362
# 429       3.1       6.4       7.4       8.0    ...            0.006519
# 80        0.0       9.3       9.3       6.4    ...            0.000746
# 421       4.4       9.5       5.2      15.9    ...            0.006392
# 324       8.9      16.5      12.1      13.7    ...            0.032593
# 355       2.2       8.9       4.1       7.8    ...            0.003794
# 170       3.3       8.5       7.4       7.8    ...            0.005427
# 179       1.2       7.3       9.5      12.5    ...            0.004538
#
#      p_cuminc_15to25  p_cuminc_25to35  p_cuminc_35to50  p_cuminc_50to75  \
# 520         0.624672         1.000000         1.000000         1.000000
# 161         0.000000         0.000000         0.000000         0.000000
# 165         0.000000         0.000000         0.000000         0.000000
# 273         0.007489         0.018212         0.046424         0.097485
# 475         0.008694         0.023823         0.064010         0.220950
# 196         0.008350         0.051344         0.102720         0.225005
# 8           0.016397         0.038951         0.059325         0.210498
# 462         0.015515         0.039457         0.104255         0.297073
# 128         0.007676         0.036834         0.104426         0.243173
# 464         0.029467         0.071161         0.125685         0.296071
# 301         0.015653         0.035039         0.101329         0.218310
# 188         0.018371         0.037156         0.083351         0.279765
# 466         0.031143         0.042052         0.092402         0.248556
# 172         0.040403         0.071172         0.190110         0.484982
# 173         0.026123         0.060736         0.137632         0.279393
# 370         0.016204         0.036600         0.088128         0.259511
# 511         0.033109         0.058016         0.157042         0.275049
# 425         0.026230         0.101152         0.165201         0.347303
# 559         0.034744         0.058323         0.089605         0.283754
# 139         0.032137         0.081415         0.165317         0.387597
# 556         0.017733         0.034126         0.082359         0.151977
# 151         0.043544         0.108665         0.273248         0.559781
# 197         0.022400         0.058534         0.113381         0.292364
# 134         0.068490         0.155244         0.323424         0.618312
# 167         0.018383         0.035618         0.095192         0.271845
# 500         0.043621         0.085688         0.145284         0.343151
# 138         0.045793         0.072725         0.108602         0.300382
# 7           0.043922         0.116151         0.291883         0.505605
# 233         0.040390         0.058771         0.127264         0.326219
# 473         0.044737         0.075828         0.146889         0.322210
# ..               ...              ...              ...              ...
# 211         0.011755         0.020112         0.037439         0.094345
# 24          0.013342         0.015522         0.028909         0.063361
# 251         0.038782         0.067536         0.121849         0.237220
# 291         0.013917         0.023183         0.038100         0.096014
# 51          0.016101         0.041844         0.081451         0.169685
# 248          0.446898           0.597337           0.673516               1.0
# 474          0.568947           0.791274           0.868173               1.0
# 307          0.272915           0.462422           0.608511               1.0
# 539          0.124818           0.273565           0.381083               1.0
# 497          0.172923           0.317992           0.469046               1.0
# 14           0.221527           0.379620           0.573475               1.0
# 65           0.153063           0.250212           0.400169               1.0
# 375          0.141936           0.273851           0.456052               1.0
# 292          0.143195           0.268191           0.400020               1.0
# 384          0.166752           0.288607           0.417156               1.0
# 379          0.189813           0.359934           0.544695               1.0
# 363          0.306085           0.450312           0.556155               1.0
# 339          0.338168           0.483206           0.584733               1.0
# 213          0.188989           0.331772           0.483694               1.0
# 331          0.229306           0.425444           0.599737               1.0
# 256          0.254831           0.437322           0.573253               1.0
# 322          0.218756           0.367583           0.485653               1.0
# 429          0.230686           0.429945           0.508783               1.0
# 80           0.133671           0.226092           0.324837               1.0
# 421          0.245572           0.415498           0.527357               1.0
# 324          0.516651           0.649683           0.755221               1.0
# 355          0.203840           0.319767           0.445850               1.0
# 170          0.234224           0.344422           0.488512               1.0
# 179          0.323817           0.432535           0.483822               1.0
#
#          gini
# 520 -0.464031
# 161  0.000000
# 165  0.000000
# 273  0.106779
# 475  0.146971
# 196  0.151569
# 8    0.153104
# 462  0.155324
# 128  0.174965
# 464  0.175376
# 301  0.177436
# 188  0.180218
# 466  0.192730
# 172  0.197013
# 173  0.207648
# 370  0.209218
# 511  0.210167
# 425  0.211051
# 559  0.211246
# 139  0.217724
# 556  0.219958
# 151  0.223843
# 197  0.223853
# 134  0.225193
# 167  0.225214
# 500  0.225283
# 138  0.226192
# 7    0.226496
# 233  0.226712
# 473  0.229532
# ..        ...
# 211  0.458492
# 24   0.458881
# 251  0.459323
# 291  0.460206
# 51   0.460282
# 37   0.461432
# 248  0.461991
# 474  0.462242
# 307  0.462275
# 539  0.463507
# 497  0.467442
# 14   0.470582
# 65   0.471319
# 375  0.472575
# 292  0.473080
# 384  0.473591
# 379  0.474082
# 363  0.475728
# 339  0.478365
# 213  0.479029
# 331  0.479107
# 256  0.481489
# 322  0.482143
# 429  0.487938
# 80   0.491367
# 421  0.494478
# 324  0.496408
# 355  0.498620
# 170  0.504985
# 179  0.506263
#
# [565 rows x 58 columns]

# %%
df_gini.iloc[520,35]
# Out:
# 100.0

# %%
## Walpack township as usual is a major outlier due to having only a population of 16
##  therefore set its gini coefficient to 0

#df_gini.info()
df_gini.iloc[520,57] = 0
df_gini.iloc[520,4]
# Out:
# 'Walpack township, Sussex County, New Jersey'

# %%
df_to_d3 = df_gini.loc[:,'FIPS':'city_town'] 
df_to_d3['cluster'] = df_gini[['gini']]
df_to_d3.columns = ['id','name','cluster']
#cluster_labels]])
df_to_d3.head()
df_to_d3.to_csv('gini_coeff.tsv',sep = '\t', index = False)

# %%
df_to_d3.describe()
# Out:
#           cluster
# count  565.000000
# mean     0.347475
# std      0.075548
# min      0.000000
# 25%      0.298138
# 50%      0.346907
# 75%      0.405243
# max      0.506263

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sb

# %%
plt.hist(df_gini['gini']);
