# %% [markdown]
# Import 2012 Unified Crime Data

# %%
# !ls Data
# Out:
# 15taxes.ods
# 15taxes.xls
# 2012LocalCrimeOneYearofData.csv
# 2012LocalCrimeOneYearofData.ods
# 20160916a_ucr_2015stats.pdf
# ACS_10_SF4_B25003.zip
# ACS_14_5YR_DP02_ann.csv
# ACS_14_5YR_DP02.csv
# ACS_14_5YR_DP02_metadata.csv
# ACS_14_5YR_DP02.txt
# ACS_14_5YR_DP02.zip
# ACS_14_5YR_DP03.zip
# ACS_14_5YR_DP04.zip
# ACS_14_5YR_DP05.zip
# aff_download_readme.txt
# bus_data.zip
# Creddle _ Content_files
# Creddle _ Content.html
# DepartureVisionPacket.zip
# njlocaltaxes.csv
# njlocaltaxes.ods
# rail_data.zip
# sustainable.csv
# TGESTaxpayerGuideToEducationSpendingInstall.pdf
# TGESTaxpayerGuideToEducationSpending.zip

# %%
import pandas as pd

# %%
crime = pd.read_csv('Data/2012LocalCrimeOneYearofData.csv')

# %%
crime.head()
# Out:
#                                       Agency State  Months  Population  \
# 0     Franklin Twp (Somerset Co) Police Dept    NJ      12       62885
# 1                   Aberdeen Twp Police Dept    NJ      12       18319
# 2  City Of Asbury Park Dept Of Public Safety    NJ      12       16211
# 3                  Atlantic City Police Dept    NJ      12       39722
# 4                   Barnegat Twp Police Dept    NJ      12       21141
#
#    Violentcrimetotal  MurderandnonnegligentManslaughter  Forciblerape  \
# 0                 72                                  1             2
# 1                 24                                  0             3
# 2                247                                  3            10
# 3                699                                 19            35
# 4                 26                                  0             0
#
#    Robbery  Aggravatedassault  Propertycrimetotal          ...            \
# ...
